# %%
#q1
def ifPrime(n):

    for i in range(2,n):
        if(n%i==0):
            flag=0
            return 0
    return 1

def rotate(num):


    rotatedList=[int("".join(map(str, num)))]
    length=len(num)-1

    for i in range(0,length):
        temp=num[0]

        for j in range(0,length):
                       num[j]=num[j+1]
        num[len(num)-1]=temp
       # print(num)
        if (int("".join(map(str, num))) not in rotatedList ):
            rotatedList.append(int("".join(map(str, num))))
    return rotatedList

def breakNum(n):
    num=[]
    while(n!=0):
        num.append(int(n%10))
        n=int(n/10)

    num.reverse()
    return num

n=2
limit=10000
circularPrimes=[]
for i in range(n,limit):

    if(len(str(i))>1):
        if(i not in circularPrimes):
                num= breakNum(i)
                rotatedList=list(rotate(num))
                count=0
                for j in rotatedList:
                    if(ifPrime(j)):
                        count=count+1
                if(count==int(len(rotatedList))):
                    for j in rotatedList:
                          circularPrimes.append(j)
    else:
        if(ifPrime(i)):
            circularPrimes.append(i)

print(len(circularPrimes))
# Out:
# 33

# %%
#q2
    
def ifPrime(n):
    if(n<=1):
        return 0
    for i in range(2,n):
        if(n%i==0):
            flag=0
            return 0
    return 1

def consecutivePrimes(primes):
    consectutive_prime=list()
    length=len(primes)
    for i in range(length,2,-1):
        j=0

        for j in range(0,length):

            if((j+(i-1))<=length):
               # print("j: "+str(j)+" k: "+str(j+i-1))
                consectutive_prime.append(primes[j:j+i-1])
            else:
                break

    return consectutive_prime



n=2
limit=100
primes=list()
maxLength=0
prime=0;
for i in range(n,limit):
    if(ifPrime(i)):
       primes.append(i)

consectutive_prime=consecutivePrimes(primes)
for i in range(0,len(consectutive_prime)):

    suM=int(sum(consectutive_prime[i]))
    if(ifPrime(suM)):
        if suM in primes:
              length=len(consectutive_prime[i])
              if(length>maxLength):
                  prime=suM
                  maxLength=length
print(prime)
print(maxLength)
# Out:
# 41
# 6

# %%
#q3
def ifPrime(n):
    if(n<=1):
        return 0
    for i in range(2,n):
        if(n%i==0):
            return 0
    return 1

def removeFromleft(n):
    temp=str(n)
 
    for i in range(1,len(temp)):
        removeLeft=temp[i:len(temp)]
        removeLeft=int(removeLeft)
        print(removeLeft)
        if(ifPrime(removeLeft)==0):
            return 0
    return 1
    
def removeFromRight(n):
    n=int(n/10)
    while(n>0):
        if(ifPrime(n)):
            n=int(n/10)
        else:
            return 0
        
    return 1
    
def ifTrunctablePrime(n):

    if(removeFromRight(n)):
        if(removeFromleft(n)):
            return 1
    return 0
    
    

n=2
limit=1000000
primes=list()
count=0
trunctablePrime=list()
for i in range(10,limit):
    if(ifPrime(i)):
       primes.append(i)

for i in primes:
    if(count==10):
        break
    if(ifTrunctablePrime(i)):
        trunctablePrime.append(i)
       
        count=count+1
suM=int(sum(trunctablePrime))
print(trunctablePrime)
print(suM)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-423ecd07d4d2> in <module>
#      44 trunctablePrime=list()
#      45 for i in range(10,limit):
# ---> 46     if(ifPrime(i)):
#      47        primes.append(i)
#      48
#
# <ipython-input-5-423ecd07d4d2> in ifPrime(n)
#       4         return 0
#       5     for i in range(2,n):
# ----> 6         if(n%i==0):
#       7             return 0
#       8     return 1
#
# KeyboardInterrupt:

# %%
#q4

def reverse(n):  
    rev = 0;  
    while (n > 0):  
       
        remainder = n % 10;  
        rev = (rev * 10) + remainder;  
        number = int(n / 10);  
      
    return rev
    
def isPalindrome(n):
    rev=reverse(n)
    if(n==rev):
        return 1;  
    return 0;  
def isLychrel(n): 
      
    for i in range(55):  
        n = n + reverse(n);  
          
        if (isPalindrome(n)):  
            return 1;  
      
    return 0;  
    
def removeFromRight(n):
    n=int(n/10)
    while(n>0):
        if(ifPrime(n)):
            n=int(n/10)
        else:
            return 0
    return 1
    
def ifTrunctablePrime(n):

    if(removeFromRight(n)):
        if(removeFromleft(n)):
            return 1
    return 0
    
    


limit=10000
count=0

for i in range(10,limit):
    if(isLychrel(i)):
       count=count+1

print(count)

# %%
#q5
class CircularQueue(): 
  
    # constructor 
    def __init__(self, size): # initializing the class 
        self.size = size 
          
        # initializing queue with none 
        self.queue = [None for i in range(size)]  
        self.front = self.rear = -1
  
    def enqueue(self, data): 
          
        # condition if queue is full 
        if ((self.rear + 1) % self.size == self.front):  
            print(" Queue is Full\n") 
              
        # condition for empty queue 
        elif (self.front == -1):  
            self.front = 0
            self.rear = 0
            self.queue[self.rear] = data 
        else: 
              
            # next position of rear 
            self.rear = (self.rear + 1) % self.size  
            self.queue[self.rear] = data 
              
    def dequeue(self): 
        if (self.front == -1): # codition for empty queue 
            print ("Queue is Empty\n") 
              
        # condition for only one element 
        elif (self.front == self.rear):  
            temp=self.queue[self.front] 
            self.front = -1
            self.rear = -1
            return temp 
        else: 
            temp = self.queue[self.front] 
            self.front = (self.front + 1) % self.size 
            return temp 

    def getfront_value(self):
        if self.front==-1:
            return "empty queue"
        else:
            mydata=self.queue[self.rear]
            return mydata

    def isEmpty(self):
        if(self.front == -1):  
            return 1
        else:
            return 0
    def display(self): 
      
        # condition for empty queue 
        if(self.front == -1):  
            print ("Queue is Empty") 
  
        elif (self.rear >= self.front): 
            print("Elements in the circular queue are:",  
                                              end = " ") 
            for i in range(self.front, self.rear + 1): 
                print(self.queue[i], end = " ") 
            print () 
  
        else: 
            print ("Elements in Circular Queue are:",  
                                           end = " ") 
            for i in range(self.front, self.size): 
                print(self.queue[i], end = " ") 
            for i in range(0, self.rear + 1): 
                print(self.queue[i], end = " ") 
            print () 
            
sizee=5
minval=999999
q=CircularQueue(sizee)
q.enqueue(5)
q.enqueue(20)
q.enqueue(3)
q.enqueue(40)
q.enqueue(2)


q.display()

if not q.isEmpty():
    start=q.dequeue()
    end=q.getfront_value()




    while(start!=end):
        if start<minval:
            minval=start
        
        q.enqueue(start)
    
        if not q.isEmpty():
            start=q.dequeue()
        
        q.enqueue(start)

    if(minval>start):
        minval=start
    
    print("min: ",minval)
else:
    print("queue is empty")
# Out:
# Elements in the circular queue are: 5 20 3 40 2
#  Queue is Full
#
#  Queue is Full
#
#  Queue is Full
#
# min:  2

# %%
#q6 
from queue import Queue 
  
class Stack: 
      
    def __init__(self): 
          
        self.q1 = Queue() 
        self.q2 = Queue()  
        self.curr_size = 0
  
    def push(self, x): 
        self.curr_size += 1 
        self.q2.put(x)    
        while (not self.q1.empty()): 
            self.q2.put(self.q1.queue[0])  
            self.q1.get() 
        self.q = self.q1  
        self.q1 = self.q2  
        self.q2 = self.q 
  
    def pop(self):  
        if (self.q1.empty()):  
            return
        self.q1.get()  
        self.curr_size -= 1
  
    def top(self): 
        if (self.q1.empty()): 
            return -1
        return self.q1.queue[0] 
  
    def size(self): 
        return self.curr_size 
  

s = Stack() 
s.push(1)  
s.push(2)  
s.push(3)  
print("current size: ", s.size()) 
print(s.top())  
s.pop()  
print(s.top())  
s.pop()  
print(s.top())  
print("current size: ", s.size())
# Out:
# current size:  3
# 3
# 2
# 1
# current size:  1
